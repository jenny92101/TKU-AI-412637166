# %% [markdown]
# <a href="https://colab.research.google.com/github/jenny92101/TKU-AI-412637166/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.13.0'

# %%
print("GPU Aailable:",tf.test.is_gpu_available())
# Out:
# WARNING:tensorflow:From <ipython-input-12-692cd5657ccf>:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Aailable: True

# %%
# !nvidia-smi
# Out:
# Tue Oct 17 00:11:21 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P0    30W /  70W |    359MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
A = tf.constant([[1,2],[3,4]])
B = tf.constant([[5,6],[7,8]])
c = tf.matmul(A,B)

# %%
print(c)
# Out:
# tf.Tensor(
# [[19 22]
#  [43 50]], shape=(2, 2), dtype=int32)

# %%
# !pip install easyocr

# %%
# !pip install easyocr opencv-python numpy

# %%
from google.colab import files

uploaded = files.upload()

# 取得上傳圖像的路徑
image_path = next(iter(uploaded))

# 讀取圖像檔案
img = cv2.imread(image_path)
# Out:
#      <input type="file" id="files-fda38c35-c6bb-44a0-b7b3-8de5a4e40211" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fda38c35-c6bb-44a0-b7b3-8de5a4e40211">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
import easyocr
import re

# 讀取圖像檔案
img = cv2.imread('11.jpeg')

# 將圖像轉為灰度圖
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# 初始化車牌識別器
reader = easyocr.Reader(['en'])

# 進行車牌識別
results = reader.readtext(gray)

# 過濾只包含英文字母和數字的文字
filtered_results = []
for result in results:
    text = result[1]
    if re.match(r'^[A-Za-z0-9]+$', text):
        filtered_results.append(result)



    # 在控制台上輸出識別的文字
    print("識別結果: {}".format(text))

    # 在圖像上繪製識別的框
    cv2.rectangle(img, (int(bbox[0][0]), int(bbox[0][1])), (int(bbox[2][0]), int(bbox[2][1])), (0, 255, 0), 2)

# 顯示處理後的圖像
from google.colab.patches import cv2_imshow
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 識別結果: 3
# 識別結果: KBF
# 識別結果: 006
# <PIL.Image.Image image mode=RGB size=1128x645>
